# %%
#importation module pandas
import pandas as pd

# %%
#Importer le csv dans un DataFrame pandas
#compression de gzip directement et lecture de csv
full_csv = pd.read_csv('https://cadastre.data.gouv.fr/data/etalab-dvf/latest/csv/2020/full.csv.gz', compression='gzip',  header=0, sep=',', quotechar='"')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (10,12,17,18,20,22,35,36) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
full_csv.head()
# Out:
#   id_mutation date_mutation  ...  longitude   latitude
# 0      2020-1    2020-01-07  ...   5.323522  46.171899
# 1      2020-2    2020-01-07  ...   5.226197  46.184538
# 2      2020-3    2020-01-14  ...        NaN        NaN
# 3      2020-3    2020-01-14  ...        NaN        NaN
# 4      2020-4    2020-01-22  ...   5.219902  46.196484
#
# [5 rows x 40 columns]

# %%
#le type de document
type(full_csv)
# Out:
# pandas.core.frame.DataFrame

# %%
#taille de ficheir
full_csv.shape
# Out:
# (827105, 40)

# %%
#ajouter une colonnne contenent vore nom
full_csv.insert(0, 'NOM_CANDIDAT', "BAGHROSSE-Rachid")
#full_csv["NOM_CANDIDAT"]="BAGHROSSE-Rachid"

# %%
full_csv['NOM_CANDIDAT']
# Out:
# 0         BAGHROSSE-Rachid
# 1         BAGHROSSE-Rachid
# 2         BAGHROSSE-Rachid
# 3         BAGHROSSE-Rachid
# 4         BAGHROSSE-Rachid
#                 ...
# 827100    BAGHROSSE-Rachid
# 827101    BAGHROSSE-Rachid
# 827102    BAGHROSSE-Rachid
# 827103    BAGHROSSE-Rachid
# 827104    BAGHROSSE-Rachid
# Name: NOM_CANDIDAT, Length: 827105, dtype: object

# %%
#Ajouter une colonne portant le nom « adresse_string »
full_csv['code_postal'] = full_csv['code_postal'].apply(str)
pays= 'FRANCE'
full_csv["adresse_string"] = (full_csv['adresse_code_voie'] + ' ' + full_csv['adresse_nom_voie'] + ', ' + full_csv['nom_commune'] + ', ' + full_csv['code_postal'] + ', '+ pays)

# %%
print(full_csv.adresse_string)
# Out:
# 0                  B063 FORTUNAT, Ceyzériat, 1250.0, FRANCE
# 1         0064 RUE DE LA CHARTREUSE, Péronnas, 1960.0, F...
# 2                  B112 VACAGNOLE, Attignat, 1340.0, FRANCE
# 3                  B112 VACAGNOLE, Attignat, 1340.0, FRANCE
# 4           3340 RUE REYER, Bourg-en-Bresse, 1000.0, FRANCE
#                                 ...
# 827100    6513 RUE MONTMARTRE, Paris 2e Arrondissement, ...
# 827101    8073 RUE REAUMUR, Paris 2e Arrondissement, 750...
# 827102    1797 RUE CHARLEMAGNE, Paris 4e Arrondissement,...
# 827103    1669 RUE CHABANAIS, Paris 2e Arrondissement, 7...
# 827104    8659 RUE SAINT-JOSEPH, Paris 2e Arrondissement...
# Name: adresse_string, Length: 827105, dtype: object

# %%
# la suppression des lignes ayant l'un de ces attributs null
full_csv.dropna(subset=['longitude', 'latitude'])
# Out:
#             NOM_CANDIDAT  ...                                     adresse_string
# 0       BAGHROSSE-Rachid  ...           B063 FORTUNAT, Ceyzériat, 1250.0, FRANCE
# 1       BAGHROSSE-Rachid  ...  0064 RUE DE LA CHARTREUSE, Péronnas, 1960.0, F...
# 4       BAGHROSSE-Rachid  ...    3340 RUE REYER, Bourg-en-Bresse, 1000.0, FRANCE
# 5       BAGHROSSE-Rachid  ...  B025 LES GUYOTS, Montrevel-en-Bresse, 1340.0, ...
# 6       BAGHROSSE-Rachid  ...     B013 CUET, Montrevel-en-Bresse, 1340.0, FRANCE
# ...                  ...  ...                                                ...
# 827100  BAGHROSSE-Rachid  ...  6513 RUE MONTMARTRE, Paris 2e Arrondissement, ...
# 827101  BAGHROSSE-Rachid  ...  8073 RUE REAUMUR, Paris 2e Arrondissement, 750...
# 827102  BAGHROSSE-Rachid  ...  1797 RUE CHARLEMAGNE, Paris 4e Arrondissement,...
# 827103  BAGHROSSE-Rachid  ...  1669 RUE CHABANAIS, Paris 2e Arrondissement, 7...
# 827104  BAGHROSSE-Rachid  ...  8659 RUE SAINT-JOSEPH, Paris 2e Arrondissement...
#
# [780131 rows x 42 columns]

# %%
#trie de resultat par date pour récupérer les plus récents enregistrements
trie=full_csv.sort_values(by='date_mutation')
trie.tail(500)
# Out:
#             NOM_CANDIDAT  ...                                     adresse_string
# 55739   BAGHROSSE-Rachid  ...  0690 RUE DES FOSSES, Nogent-sur-Seine, 10400.0...
# 55738   BAGHROSSE-Rachid  ...  0690 RUE DES FOSSES, Nogent-sur-Seine, 10400.0...
# 55737   BAGHROSSE-Rachid  ...  0690 RUE DES FOSSES, Nogent-sur-Seine, 10400.0...
# 615123  BAGHROSSE-Rachid  ...       0140 BD CARNOT, Hardricourt, 78250.0, FRANCE
# 615124  BAGHROSSE-Rachid  ...  0038 RUE DE LA BATELLERIE, Carrières-sous-Pois...
# ...                  ...  ...                                                ...
# 55942   BAGHROSSE-Rachid  ...        2880 RUE JEANNETTE, Troyes, 10000.0, FRANCE
# 55941   BAGHROSSE-Rachid  ...        2880 RUE JEANNETTE, Troyes, 10000.0, FRANCE
# 55940   BAGHROSSE-Rachid  ...        2880 RUE JEANNETTE, Troyes, 10000.0, FRANCE
# 564068  BAGHROSSE-Rachid  ...  0742 RUE DE LA NOBLE EPINE, Bois-Guillaume, 76...
# 709439  BAGHROSSE-Rachid  ...            B037 LE PAUMIER, Crain, 89480.0, FRANCE
#
# [500 rows x 42 columns]

# %%
# !pip install requests 
import requests

AIRTABLE_BASE_ID="appqmv1skloVlLyKV"
AIRTABLE_API_KEY="keyXZ6Vj7qiD173Zs"
AIRTABLE_TABLE_NAME="DVF"

endpoint=f'https://api.airtable.com/v0/{AIRTABLE_BASE_ID}/{AIRTABLE_TABLE_NAME}'

 #trie de resultat par date
dataTrie=full_csv.sort_values(by='date_mutation')
data = dataTrie[["NOM_CANDIDAT","id_mutation","date_mutation","numero_disposition","nature_mutation","valeur_fonciere","adresse_numero","adresse_code_voie","code_postal","code_commune","code_departement","nombre_lots","code_type_local","type_local","surface_reelle_bati","nombre_pieces_principales","code_nature_culture","nature_culture","surface_terrain","longitude","latitude","adresse_string"]].tail(3).copy()
parse = json.loads(data.to_json(orient="records"))

#affichage 
"""
print(parse[0]);====> affiche un objet comme la suite
 {'NOM_CANDIDAT': 'BAGHROSSE-Rachid', 'id_mutation': '2020-24880',
 'date_mutation': '2020-06-30', 'numero_disposition': 1, 'nature_mutation': 'Vente',
  'valeur_fonciere': 160000.0, 'adresse_numero': 11.0, 'adresse_code_voie': '2880',
   'code_postal': '10000.0', 'code_commune': 10387, 'code_departement': 10, 'nombre_lots': 1,
    'code_type_local': 3.0, 'type_local': 'Dépendance', 'surface_reelle_bati': None,
     'nombre_pieces_principales': 0.0, 'code_nature_culture': None, 'nature_culture': None,
      'surface_terrain': None, 'longitude': 4.086842, 'latitude': 48.282919,
       'adresse_string': '2880 RUE JEANNETTE, Troyes, 10000.0, FRANCE'}
"""
#ajouter les données sur airtable
#chaque ligne representre un objet avec sous format json avec tous les champs requis
for i in range(len(parse)):

  headers = {
    "Authorization": f"Bearer {AIRTABLE_API_KEY}",
    "Content-Type": "application/json"
                }
  data = {
      "records": [
             {
              "fields":
                parse[i] 
                        }
                    ]
                }
  #API post request               
  r = requests.post(endpoint, json=data, headers=headers)
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)
